# %% [markdown]
# ## Implementar LDA

# %%
#Las hipótesis de las funciones a posteriori son un vector de datos con distribución normal multivariadas
#Necesitamos una matriz positiva definida

# %% [markdown]
# Creamos un conjunto de datos

# %%
import numpy as np

mu1=[0,0] #Suponemos que el vector es centrado porque todos se pueden centrar
sigma1=np.array([[1,0.5],[0.5,1]]) #Esta es la matriz de varianzas
sigma2=np.array([[1,0.5],[0.5,1]])

X=np.random.multivariate_normal(mu1,sigma1,5000)
X
# Out:
# array([[ 0.24801669, -0.39766656],
#        [ 0.62834151, -0.10248401],
#        [-0.40365061, -1.93784783],
#        ...,
#        [-0.35129945, -0.60015633],
#        [ 0.00391482, -0.9325022 ],
#        [-1.26851747, -1.41612622]])

# %%
#Estos son los accesos:
X[2000:,0]=X[2000:,0]+2 #Los dos puntos son para que elija todo
X[2000:,1]=X[2000:,1]+2

# %%
y=np.ones((5000,))

y[:2000]=0

# %%
X[2:6,:]
# Out:
# array([[-0.40365061, -1.93784783],
#        [-1.64476085, -1.33926444],
#        [-0.33897683,  0.27461948],
#        [-0.97788907, -0.50746045]])

# %%
y[:6]
# Out:
# array([0., 0., 0., 0., 0., 0.])

# %%
def c(x):
  a=x**2
  return a

# %%
c(4)
# Out:
# 16

# %%
import matplotlib.pyplot as plt
from math import exp

fig,ax=plt.subplots(1,1,figsize=(16,9))
plt.scatter(X[:,0],X[:,1],c=list(exp(lambda x:"blue" if x==0 else "red",y)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-05bfcc076d53> in <cell line: 5>()
#       3
#       4 fig,ax=plt.subplots(1,1,figsize=(16,9))
# ----> 5 plt.scatter(X[:,0],X[:,1],c=list(exp(lambda x:"blue" if x==0 else "red",y)))
#       6 plt.show()
#
# TypeError: math.exp() takes exactly one argument (2 given)
